# %% [markdown]
# Panggil semua library yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# **Gathering Data**

# %%
customers_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/customers.csv")
customers_df.head()
# Out:
#    customer_id customer_name             gender  age  \
# 0            1       fulan 1             Female   30
# 1            2       fulan 2  Prefer not to say   69
# 2            3       fulan 3  Prefer not to say   59
# 3            4       fulan 4  Prefer not to say   67
# 4            5       fulan 5  Prefer not to say   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# 4                    Queensland  Australia

# %%
orders_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/orders.csv")
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
product_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/products.csv")
product_df.head()
# Out:
#    product_id product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
sales_df = pd.read_csv("https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/DicodingCollection/sales.csv")
sales_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 0         0         1         218             106         2        212.0
# 1         1         1         481             118         1        118.0
# 2         2         1           2              96         3        288.0
# 3         3         1        1002             106         2        212.0
# 4         4         1         691             113         3        339.0

# %% [markdown]
# **Assessing Data**

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    1007 non-null   int64
#  1   customer_name  1007 non-null   object
#  2   gender         989 non-null    object
#  3   age            1007 non-null   int64
#  4   home_address   1007 non-null   object
#  5   zip_code       1007 non-null   int64
#  6   city           1007 non-null   object
#  7   state          1007 non-null   object
#  8   country        1007 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.9+ KB

# %%
customers_df.isna().sum()
# Out:
# customer_id       0
# customer_name     0
# gender           18
# age               0
# home_address      0
# zip_code          0
# city              0
# state             0
# country           0
# dtype: int64

# %%
print("Jumlah duplikasi: ", customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %%
customers_df.describe()
# Out:
#        customer_id          age     zip_code
# count  1007.000000  1007.000000  1007.000000
# mean    501.726912    50.929494  5012.538232
# std     288.673238    30.516299  2885.836112
# min       1.000000    20.000000     2.000000
# 25%     252.500000    34.000000  2403.500000
# 50%     502.000000    50.000000  5087.000000
# 75%     751.500000    65.000000  7493.500000
# max    1000.000000   700.000000  9998.000000

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   object
#  4   delivery_date  1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
print("Jumlah duplikasi: ",orders_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
print(orders_df.describe(include='all'))
# Out:
#            order_id  customer_id       payment order_date delivery_date
# count   1000.000000  1000.000000   1000.000000       1000          1000
# unique          NaN          NaN           NaN        291           305
# top             NaN          NaN           NaN  2021-6-20    2021-08-09
# freq            NaN          NaN           NaN         10             9
# mean     500.500000   506.640000  33972.936000        NaN           NaN
# std      288.819436   277.115502  14451.609047        NaN           NaN
# min        1.000000     1.000000  10043.000000        NaN           NaN
# 25%      250.750000   275.250000  21329.250000        NaN           NaN
# 50%      500.500000   515.000000  33697.500000        NaN           NaN
# 75%      750.250000   737.250000  46249.000000        NaN           NaN
# max     1000.000000  1000.000000  59910.000000        NaN           NaN

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1266 entries, 0 to 1265
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    1266 non-null   int64
#  1   product_type  1266 non-null   object
#  2   product_name  1266 non-null   object
#  3   size          1266 non-null   object
#  4   colour        1266 non-null   object
#  5   price         1266 non-null   int64
#  6   quantity      1266 non-null   int64
#  7   description   1266 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 79.3+ KB

# %%
print("Jumlah duplikasi: ", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  6

# %%
product_df.describe()
# Out:
#         product_id        price     quantity
# count  1266.000000  1266.000000  1266.000000
# mean    627.926540   105.812006    60.138231
# std     363.971586     9.715611    11.682791
# min       0.000000    90.000000    40.000000
# 25%     313.250000    95.250000    50.000000
# 50%     626.500000   109.000000    60.000000
# 75%     942.750000   114.000000    70.000000
# max    1259.000000   119.000000    80.000000

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sales_id        5000 non-null   int64
#  1   order_id        5000 non-null   int64
#  2   product_id      5000 non-null   int64
#  3   price_per_unit  5000 non-null   int64
#  4   quantity        5000 non-null   int64
#  5   total_price     4981 non-null   float64
# dtypes: float64(1), int64(5)
# memory usage: 234.5 KB

# %%
sales_df.isna().sum()
# Out:
# sales_id           0
# order_id           0
# product_id         0
# price_per_unit     0
# quantity           0
# total_price       19
# dtype: int64

# %%
print("Jumlah duplikasi: ", sales_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sales_df.describe()
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  4981.000000
# mean    206.307368
# std      86.352449
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %% [markdown]
# **Cleaning Data**

# %%
customers_df.drop_duplicates(inplace=True)
print('Jumlah duplikasi:',customers_df.duplicated().sum())
# Out:
# Jumlah duplikasi: 0

# %%
customers_df[customers_df['gender'].isna()]
# Out:
#      customer_id customer_name gender  age                     home_address  \
# 38            39      fulan 39    NaN   80  7440 Cameron Estate DrSuite 628
# 167          168     fulan 168    NaN   27         2781 Berge MallSuite 452
# 322          322     fulan 322    NaN   30        593 Becker CircleApt. 333
# 393          393     fulan 393    NaN   34          5158 Levi HillSuite 531
# 442          442     fulan 442    NaN   26           5157 Feil RoadApt. 633
# 722          720     fulan 720    NaN   40         31 Jordan ParadeApt. 400
# 745          743     fulan 743    NaN   57   09 Christopher StreetSuite 967
# 773          771     fulan 771    NaN   74     7367 Wright JunctionApt. 773
# 798          795     fulan 795    NaN   49          487 Summer MewsApt. 874
# 801          798     fulan 798    NaN   56           27 Aiden KnollApt. 875
# 825          822     fulan 822    NaN   59        41 Jenkins KnollSuite 438
# 859          855     fulan 855    NaN   55       603 O'keefe KnollSuite 782
# 863          859     fulan 859    NaN   38            32 Isla GroveApt. 078
# 914          909     fulan 909    NaN   62    976 Murray Station StApt. 036
# 934          929     fulan 929    NaN   68           394 Lily HillSuite 153
# 948          943     fulan 943    NaN   64       3117 Heller PlaceSuite 149
# 952          946     fulan 946    NaN   24      8227 Nicholas HillSuite 150
# 994          988     fulan 988    NaN   35   1130 Turner Estate DrSuite 925
#
#      zip_code                   city                         state    country
# 38       4622  North Victoriachester            Northern Territory  Australia
# 167      1975         North Leoburgh             Western Australia  Australia
# 322      1640             Jacobiview             Western Australia  Australia
# 393      1474             Johnsburgh                    Queensland  Australia
# 442      7249             Port Chloe               New South Wales  Australia
# 722      1380             West Henry               South Australia  Australia
# 745      6226         Lake Lukemouth             Western Australia  Australia
# 773      8882               Kuhntown                      Victoria  Australia
# 798      1712            East Hayden  Australian Capital Territory  Australia
# 801      6531               Port Sam  Australian Capital Territory  Australia
# 825      2588        Lake Andrewport               South Australia  Australia
# 859      8822        Port Dylanmouth                      Tasmania  Australia
# 863      7711            Rosechester               New South Wales  Australia
# 914      3227               Langfort                      Tasmania  Australia
# 934      2353             Beahanfurt            Northern Territory  Australia
# 948       822           North Elijah               South Australia  Australia
# 952       115           South Jasper                    Queensland  Australia
# 994      9386              New Harry             Western Australia  Australia

# %%
customers_df['gender'].value_counts()
# Out:
# gender
# Prefer not to say    725
# Male                 143
# Female               115
# Name: count, dtype: int64

# %%
customers_df['gender'].fillna(value='Prefer not to say', inplace=True)
print(customers_df.isna().sum())
# Out:
# customer_id      0
# customer_name    0
# gender           0
# age              0
# home_address     0
# zip_code         0
# city             0
# state            0
# country          0
# dtype: int64

# %%
customers_df[customers_df['age']==customers_df['age'].max()]
# Out:
#      customer_id customer_name             gender  age  \
# 967          961     fulan 961  Prefer not to say  700
#
#                    home_address  zip_code        city            state  \
# 967  29 Farrell ParadeSuite 818      6528  New Joseph  South Australia
#
#        country
# 967  Australia

# %%
customers_df['age'].replace(customers_df['age'].max(), 70, inplace=True)
customers_df[customers_df['age']==customers_df['age'].max()]
# Out:
#      customer_id customer_name             gender  age  \
# 215          216     fulan 216  Prefer not to say  500
#
#                home_address  zip_code       city               state  \
# 215  038 Haley MewsApt. 810      3991  Bayertown  Northern Territory
#
#        country
# 215  Australia

# %%
customers_df['age'].replace(customers_df['age'].max(), 50, inplace=True)
customers_df[customers_df['age']==customers_df['age'].max()]
# Out:
#      customer_id customer_name             gender  age  \
# 34            35      fulan 35               Male   80
# 38            39      fulan 39  Prefer not to say   80
# 142          143     fulan 143  Prefer not to say   80
# 154          155     fulan 155               Male   80
# 170          171     fulan 171  Prefer not to say   80
# 174          175     fulan 175  Prefer not to say   80
# 181          182     fulan 182               Male   80
# 235          236     fulan 236  Prefer not to say   80
# 424          424     fulan 424  Prefer not to say   80
# 438          438     fulan 438  Prefer not to say   80
# 495          495     fulan 495               Male   80
# 524          524     fulan 524  Prefer not to say   80
# 598          597     fulan 597  Prefer not to say   80
# 703          702     fulan 702  Prefer not to say   80
# 734          732     fulan 732  Prefer not to say   80
#
#                           home_address  zip_code                   city  \
# 34   3168 Bartoletti CrescentSuite 878       593             Port Lucas
# 38     7440 Cameron Estate DrSuite 628      4622  North Victoriachester
# 142        87 Hahn Station StSuite 943      8254               New Ella
# 154           85 Charles MallSuite 424      7841            Port Sophia
# 170              16 Boyer WaySuite 018      6226          South Gabriel
# 174             57 David MallSuite 596      3129                Haneton
# 181           32 Thomas CrestSuite 753      2147             Archiefurt
# 235            64 Phillips RunApt. 722      2752            East Sienna
# 424            03 Grant CrestSuite 228      5743      Lake Charliemouth
# 438          569 Alyssa IslandApt. 766      6893             Hunterland
# 495          1798 Schultz MewsApt. 704      9409           Lake Caitlin
# 524            0358 Ashley WayApt. 506      3345     Port Sebastianland
# 598          78 O'hara CircuitApt. 096      1966       Lake Michaelbury
# 703              61 Bosco WaySuite 775       685        Thompsonborough
# 734    905 Stephanie BoulevardApt. 217      8114          Port Aaronton
#
#                   state    country
# 34           Queensland  Australia
# 38   Northern Territory  Australia
# 142            Victoria  Australia
# 154     New South Wales  Australia
# 170   Western Australia  Australia
# 174     South Australia  Australia
# 181          Queensland  Australia
# 235     New South Wales  Australia
# 424   Western Australia  Australia
# 438   Western Australia  Australia
# 495     New South Wales  Australia
# 524          Queensland  Australia
# 598     South Australia  Australia
# 703   Western Australia  Australia
# 734          Queensland  Australia

# %%
customers_df.describe(include='all')
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     500.942058           NaN                NaN    49.874126
# std      289.013599           NaN                NaN    17.644663
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN    80.000000
#
#                       home_address     zip_code     city            state  \
# count                         1001  1001.000000     1001             1001
# unique                        1000          NaN      961                8
# top     3117 Heller PlaceSuite 149          NaN  New Ava  South Australia
# freq                             2          NaN        3              140
# mean                           NaN  5000.693307      NaN              NaN
# std                            NaN  2886.084454      NaN              NaN
# min                            NaN     2.000000      NaN              NaN
# 25%                            NaN  2398.000000      NaN              NaN
# 50%                            NaN  5079.000000      NaN              NaN
# 75%                            NaN  7454.000000      NaN              NaN
# max                            NaN  9998.000000      NaN              NaN
#
#           country
# count        1001
# unique          1
# top     Australia
# freq         1001
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
column_date=['order_date','delivery_date']

for column in column_date:
  orders_df[column] = pd.to_datetime(orders_df[column])

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1000 non-null   int64
#  1   customer_id    1000 non-null   int64
#  2   payment        1000 non-null   int64
#  3   order_date     1000 non-null   datetime64[ns]
#  4   delivery_date  1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), int64(3)
# memory usage: 39.2 KB

# %%
product_df.drop_duplicates(inplace=True)
print("Jumlah duplikasi: ", product_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
sales_df[sales_df['total_price'].isna()]
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity  total_price
# 9            9         2        1196             105         1          NaN
# 121        121        27        1027              90         3          NaN
# 278        278        63         360              94         2          NaN
# 421        421        95        1091             115         1          NaN
# 489        489       108        1193             105         3          NaN
# 539        539       117         405             119         2          NaN
# 636        636       134         653              93         3          NaN
# 687        687       145        1138             102         1          NaN
# 854        854       177          64             104         1          NaN
# 1079      1079       222         908              94         3          NaN
# 1193      1193       248        1121             102         2          NaN
# 1313      1313       272         826             117         1          NaN
# 1548      1548       316         103             118         3          NaN
# 1688      1688       345         428             107         1          NaN
# 1775      1775       359         694             113         2          NaN
# 1902      1902       381        1218             105         3          NaN
# 2025      2025       408         611             112         3          NaN
# 2164      2164       436         583             100         3          NaN
# 2347      2347       476         696             113         2          NaN

# %%
sales_df['total_price'] = sales_df['price_per_unit']*sales_df['quantity']
sales_df.isna().sum()
# Out:
# sales_id          0
# order_id          0
# product_id        0
# price_per_unit    0
# quantity          0
# total_price       0
# dtype: int64

# %% [markdown]
# **Exploratory Data Analysis**

# %% [markdown]
# Eksplorasi Data customers_df

# %%
customers_df.describe(include='all')
# Out:
#         customer_id customer_name             gender          age  \
# count   1001.000000          1001               1001  1001.000000
# unique          NaN          1000                  3          NaN
# top             NaN     fulan 943  Prefer not to say          NaN
# freq            NaN             2                743          NaN
# mean     500.942058           NaN                NaN    49.874126
# std      289.013599           NaN                NaN    17.644663
# min        1.000000           NaN                NaN    20.000000
# 25%      251.000000           NaN                NaN    34.000000
# 50%      501.000000           NaN                NaN    50.000000
# 75%      751.000000           NaN                NaN    65.000000
# max     1000.000000           NaN                NaN    80.000000
#
#                       home_address     zip_code     city            state  \
# count                         1001  1001.000000     1001             1001
# unique                        1000          NaN      961                8
# top     3117 Heller PlaceSuite 149          NaN  New Ava  South Australia
# freq                             2          NaN        3              140
# mean                           NaN  5000.693307      NaN              NaN
# std                            NaN  2886.084454      NaN              NaN
# min                            NaN     2.000000      NaN              NaN
# 25%                            NaN  2398.000000      NaN              NaN
# 50%                            NaN  5079.000000      NaN              NaN
# 75%                            NaN  7454.000000      NaN              NaN
# max                            NaN  9998.000000      NaN              NaN
#
#           country
# count        1001
# unique          1
# top     Australia
# freq         1001
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
customers_df.groupby('gender').agg({
    'customer_id':'nunique',
    'age': ['min','max','mean','std']
})
# Out:
#                   customer_id age
#                       nunique min max       mean        std
# gender
# Female                    115  20  79  49.147826  16.646607
# Male                      143  20  80  51.230769  18.462635
# Prefer not to say         742  20  80  49.725437  17.644283

# %%
print(customers_df.groupby("city")['customer_id'].nunique().sort_values(ascending=False))
# Out:
# city
# East Aidan       3
# East Sophia      3
# New Ava          3
# West Jackfort    2
# Corkeryshire     2
#                 ..
# Jordanside       1
# Josephland       1
# Josephmouth      1
# Justinport       1
# Zacville         1
# Name: customer_id, Length: 961, dtype: int64

# %%
print(customers_df.groupby("state")['customer_id'].nunique().sort_values(ascending=False))
# Out:
# state
# South Australia                 139
# Queensland                      134
# New South Wales                 132
# Northern Territory              125
# Western Australia               124
# Australian Capital Territory    121
# Victoria                        121
# Tasmania                        104
# Name: customer_id, dtype: int64

# %% [markdown]
# Eksplorasi Data orders_df

# %%
delivery_time_per_day = orders_df["delivery_date"] - orders_df["order_date"]
delivery_time_per_day = delivery_time_per_day.apply(lambda x: x.total_seconds())
orders_df["delivery_time_per_day"] = round(delivery_time_per_day/86400)
print(orders_df.sample(5))
# Out:
#      order_id  customer_id  payment order_date delivery_date  \
# 707       708          687    56307 2021-10-24    2021-11-10
# 384       385          146    43155 2021-08-08    2021-08-24
# 300       301          535    12986 2021-06-21    2021-06-25
# 725       726          447    28356 2021-09-15    2021-10-05
# 236       237          829    20267 2021-03-16    2021-04-06
#
#      delivery_time_per_day
# 707                   17.0
# 384                   16.0
# 300                    4.0
# 725                   20.0
# 236                   21.0

# %%
orders_df.describe(include='all')
# Out:
#           order_id  customer_id       payment                  order_date  \
# count  1000.000000  1000.000000   1000.000000                        1000
# mean    500.500000   506.640000  33972.936000  2021-05-27 18:38:52.800000
# min       1.000000     1.000000  10043.000000         2021-01-01 00:00:00
# 25%     250.750000   275.250000  21329.250000         2021-03-13 18:00:00
# 50%     500.500000   515.000000  33697.500000         2021-05-27 12:00:00
# 75%     750.250000   737.250000  46249.000000         2021-08-12 06:00:00
# max    1000.000000  1000.000000  59910.000000         2021-10-24 00:00:00
# std     288.819436   277.115502  14451.609047                         NaN
#
#              delivery_date  delivery_time_per_day
# count                 1000            1000.000000
# mean   2021-06-10 20:31:12              14.078000
# min    2021-01-03 00:00:00               1.000000
# 25%    2021-03-28 00:00:00               8.000000
# 50%    2021-06-11 12:00:00              14.000000
# 75%    2021-08-24 06:00:00              21.000000
# max    2021-11-20 00:00:00              27.000000
# std                    NaN               7.707225

# %%
customer_id_in_orders_df =  orders_df['customer_id'].tolist()
print(customer_id_in_orders_df)
# Out:
# [64, 473, 774, 433, 441, 800, 626, 58, 852, 659, 785, 120, 204, 957, 468, 564, 614, 299, 513, 789, 124, 180, 652, 469, 562, 732, 443, 206, 993, 260, 727, 627, 588, 412, 358, 51, 78, 809, 466, 86, 790, 690, 570, 849, 571, 922, 791, 620, 336, 454, 399, 493, 528, 195, 873, 587, 163, 332, 843, 301, 158, 93, 556, 167, 388, 631, 504, 180, 96, 802, 795, 610, 965, 391, 68, 470, 680, 681, 236, 872, 736, 927, 537, 181, 251, 874, 325, 567, 448, 809, 803, 273, 908, 629, 413, 415, 106, 257, 291, 817, 807, 846, 209, 366, 456, 573, 127, 935, 554, 607, 794, 75, 565, 160, 492, 510, 971, 639, 545, 585, 549, 732, 471, 776, 321, 326, 51, 936, 428, 439, 629, 562, 878, 12, 942, 539, 298, 331, 871, 539, 528, 237, 828, 928, 871, 912, 818, 573, 500, 462, 357, 320, 727, 674, 834, 727, 909, 828, 208, 725, 566, 431, 84, 412, 389, 113, 595, 664, 996, 867, 443, 224, 435, 497, 309, 574, 315, 236, 161, 469, 241, 461, 715, 240, 945, 833, 401, 571, 586, 421, 18, 842, 846, 415, 92, 630, 110, 640, 206, 15, 325, 129, 369, 568, 267, 654, 644, 28, 292, 723, 515, 62, 678, 288, 526, 865, 234, 606, 667, 555, 473, 368, 657, 628, 664, 28, 406, 773, 107, 497, 731, 256, 996, 133, 767, 228, 829, 328, 530, 578, 401, 909, 263, 637, 191, 641, 68, 457, 86, 518, 433, 683, 179, 571, 605, 313, 914, 742, 878, 317, 250, 812, 372, 636, 189, 623, 34, 530, 89, 711, 469, 92, 828, 19, 329, 775, 659, 510, 620, 551, 489, 423, 303, 522, 882, 998, 799, 201, 977, 364, 112, 337, 426, 499, 412, 207, 256, 58, 994, 912, 535, 156, 758, 537, 234, 747, 679, 549, 390, 348, 807, 683, 266, 95, 239, 179, 876, 433, 933, 41, 833, 686, 852, 99, 318, 199, 710, 246, 820, 887, 414, 466, 367, 539, 485, 615, 341, 630, 409, 841, 602, 348, 673, 526, 711, 739, 209, 732, 847, 869, 478, 52, 774, 18, 46, 236, 70, 796, 661, 870, 988, 96, 882, 925, 485, 334, 181, 556, 729, 986, 727, 991, 581, 981, 655, 571, 21, 623, 467, 75, 258, 791, 469, 709, 146, 458, 341, 601, 643, 206, 726, 840, 803, 508, 728, 461, 446, 13, 331, 907, 94, 537, 980, 998, 493, 892, 835, 404, 206, 47, 771, 427, 589, 212, 947, 129, 729, 918, 745, 482, 691, 375, 507, 551, 606, 776, 282, 431, 754, 155, 325, 20, 419, 940, 886, 739, 269, 989, 286, 553, 726, 693, 966, 383, 893, 283, 100, 185, 163, 648, 566, 123, 371, 441, 1, 450, 490, 757, 853, 250, 244, 769, 641, 103, 7, 628, 102, 238, 907, 810, 282, 85, 61, 571, 696, 757, 97, 452, 51, 180, 227, 111, 742, 926, 969, 643, 926, 638, 77, 816, 783, 568, 895, 740, 352, 574, 900, 647, 690, 571, 706, 485, 937, 192, 737, 648, 58, 834, 676, 125, 282, 223, 950, 740, 23, 506, 797, 196, 244, 679, 382, 761, 516, 60, 986, 55, 79, 343, 767, 467, 742, 523, 558, 49, 585, 927, 203, 754, 609, 772, 490, 282, 769, 347, 439, 664, 163, 135, 401, 26, 330, 264, 49, 842, 922, 566, 504, 729, 611, 11, 764, 632, 611, 583, 442, 614, 104, 783, 757, 81, 472, 479, 736, 434, 54, 218, 840, 926, 501, 171, 708, 783, 290, 142, 844, 998, 402, 612, 692, 898, 588, 973, 515, 711, 10, 693, 107, 638, 308, 921, 916, 987, 549, 492, 402, 692, 648, 530, 25, 735, 155, 486, 682, 732, 690, 21, 371, 882, 225, 614, 102, 587, 808, 398, 233, 348, 680, 534, 904, 644, 460, 952, 183, 327, 50, 793, 886, 548, 906, 873, 20, 835, 778, 207, 794, 369, 439, 522, 840, 739, 581, 691, 629, 417, 333, 907, 479, 201, 328, 787, 427, 924, 836, 21, 176, 456, 737, 22, 247, 1, 156, 677, 326, 300, 896, 889, 267, 711, 308, 800, 463, 454, 276, 956, 851, 799, 341, 574, 884, 941, 78, 697, 714, 634, 92, 230, 830, 821, 311, 788, 659, 310, 327, 260, 107, 844, 589, 687, 772, 134, 228, 474, 241, 50, 225, 502, 696, 665, 387, 465, 755, 401, 135, 394, 674, 447, 852, 526, 1, 88, 214, 40, 387, 623, 754, 793, 453, 144, 211, 178, 710, 750, 909, 107, 643, 445, 299, 27, 693, 758, 254, 535, 40, 778, 123, 318, 632, 781, 857, 207, 198, 83, 974, 955, 660, 929, 169, 558, 422, 868, 970, 573, 998, 416, 348, 265, 431, 42, 698, 100, 465, 872, 683, 436, 445, 472, 44, 108, 762, 187, 476, 240, 258, 418, 427, 592, 908, 825, 651, 422, 995, 501, 625, 323, 416, 684, 636, 219, 73, 768, 764, 183, 908, 664, 572, 620,  ...

# %%
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df
                                                           else "Non Active")
customers_df.sample(5)
# Out:
#      customer_id customer_name             gender  age  \
# 537          537     fulan 537  Prefer not to say   45
# 926          921     fulan 921  Prefer not to say   73
# 457          457     fulan 457               Male   27
# 167          168     fulan 168  Prefer not to say   27
# 346          346     fulan 346  Prefer not to say   40
#
#                        home_address  zip_code              city  \
# 537        155 Hayes AvenueApt. 699      7342          Krisland
# 926  1189 Hettinger SummitSuite 723      1758   Port Zoeborough
# 457     85 Mitchell StreetSuite 398      1849  Charlotteborough
# 167        2781 Berge MallSuite 452      1975    North Leoburgh
# 346     59 Bergstrom GroveSuite 260      6060         Olsonbury
#
#                             state    country      status
# 537             Western Australia  Australia      Active
# 926  Australian Capital Territory  Australia      Active
# 457                      Victoria  Australia      Active
# 167             Western Australia  Australia  Non Active
# 346            Northern Territory  Australia      Active

# %%
customers_df['status'].value_counts()
# Out:
# status
# Active        617
# Non Active    384
# Name: count, dtype: int64

# %% [markdown]
# Eksplorasi data orders_df dan customers_df

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date  \
# 0         1           64    30811 2021-08-30    2021-09-24
# 1         2          473    50490 2021-02-03    2021-02-13
# 2         3          774    46763 2021-10-08    2021-11-03
# 3         4          433    39782 2021-05-06    2021-05-19
# 4         5          441    14719 2021-03-23    2021-03-24
#
#    delivery_time_per_day customer_name             gender  age  \
# 0                   25.0      fulan 64  Prefer not to say   75
# 1                   10.0     fulan 473               Male   61
# 2                   26.0     fulan 774  Prefer not to say   34
# 3                   13.0     fulan 433  Prefer not to say   46
# 4                    1.0     fulan 441  Prefer not to say   53
#
#                     home_address  zip_code                city  \
# 0      4927 Alice MeadowApt. 960      7787      Sanfordborough
# 1  531 Schmitt BoulevardApt. 010      1744             Annaton
# 2       2096 Wilson MewsApt. 714      8590  West Jonathanshire
# 3        5777 Mayer PassApt. 881      9728    West Michaelport
# 4   33 Richards JunctionApt. 478      7650     South Rileyview
#
#                state    country  status
# 0    South Australia  Australia  Active
# 1    South Australia  Australia  Active
# 2           Tasmania  Australia  Active
# 3           Tasmania  Australia  Active
# 4  Western Australia  Australia  Active

# %% [markdown]
# jumlah order berdasarkan kota

# %%
orders_customers_df_city = orders_customers_df.groupby("city")['order_id'].nunique().sort_values(ascending=False).reset_index().head(10)
print(orders_customers_df_city)
# Out:
#                city  order_id
# 0        Jordanside         6
# 1           New Ava         6
# 2         Lake Rose         5
# 3        O'keefeton         5
# 4          East Max         5
# 5  Port Hannahburgh         5
# 6          Rubyfort         5
# 7          West Kai         5
# 8     Andrewborough         4
# 9     Port Aaronton         4

# %% [markdown]
# Jumlah order berdasarkan state

# %%
orders_customers_df_state = orders_customers_df.groupby("state")['order_id'].nunique().sort_values(ascending=False)
print(orders_customers_df_state)
# Out:
# state
# South Australia                 148
# Queensland                      139
# Western Australia               130
# New South Wales                 129
# Australian Capital Territory    118
# Victoria                        118
# Tasmania                        112
# Northern Territory              106
# Name: order_id, dtype: int64

# %% [markdown]
# Jumlah order berdasarkan gender

# %%
orders_customers_df_gender = orders_customers_df.groupby("gender")['order_id'].nunique().sort_values(ascending=False)
print(orders_customers_df_gender)
# Out:
# gender
# Prefer not to say    725
# Female               139
# Male                 136
# Name: order_id, dtype: int64

# %% [markdown]
# Jumlah order berdasarkan usia

# %%
orders_customers_df["age_group"] = orders_customers_df['age'].apply(lambda x: "Youth" if x <= 24 else ("Seniors" if x > 64 else "Adults"))
orders_customers_df_age = orders_customers_df.groupby("age_group")['order_id'].nunique().sort_values(ascending=False)
print(orders_customers_df_age)
# Out:
# age_group
# Adults     681
# Seniors    226
# Youth       93
# Name: order_id, dtype: int64

# %% [markdown]
# Eksplorasi data product_df & sales_df

# %%
product_df.describe(include='all')
# Out:
#          product_id product_type product_name  size colour        price  \
# count   1260.000000         1260         1260  1260   1260  1260.000000
# unique          NaN            3           35     8      7          NaN
# top             NaN        Shirt        Denim    XS    red          NaN
# freq            NaN          420           70   252    180          NaN
# mean     629.500000          NaN          NaN   NaN    NaN   105.805556
# std      363.874979          NaN          NaN   NaN    NaN     9.704423
# min        0.000000          NaN          NaN   NaN    NaN    90.000000
# 25%      314.750000          NaN          NaN   NaN    NaN    95.750000
# 50%      629.500000          NaN          NaN   NaN    NaN   108.500000
# 75%      944.250000          NaN          NaN   NaN    NaN   114.000000
# max     1259.000000          NaN          NaN   NaN    NaN   119.000000
#
#            quantity                                   description
# count   1260.000000                                          1260
# unique          NaN                                          1260
# top             NaN  A red coloured, XS sized, Oxford Cloth Shirt
# freq            NaN                                             1
# mean      60.150000                                           NaN
# std       11.670573                                           NaN
# min       40.000000                                           NaN
# 25%       50.000000                                           NaN
# 50%       60.000000                                           NaN
# 75%       70.000000                                           NaN
# max       80.000000                                           NaN

# %%
sales_df.describe(include='all')
# Out:
#           sales_id     order_id   product_id  price_per_unit    quantity  \
# count  5000.000000  5000.000000  5000.000000     5000.000000  5000.00000
# mean   2499.500000   503.038200   634.053200      103.501600     1.99240
# std    1443.520003   285.964418   363.255794        9.195004     0.80751
# min       0.000000     1.000000     1.000000       90.000000     1.00000
# 25%    1249.750000   258.000000   323.000000       95.000000     1.00000
# 50%    2499.500000   504.500000   635.000000      102.000000     2.00000
# 75%    3749.250000   749.000000   951.000000      112.000000     3.00000
# max    4999.000000   999.000000  1259.000000      119.000000     3.00000
#
#        total_price
# count  5000.000000
# mean    206.360000
# std      86.357457
# min      90.000000
# 25%     112.000000
# 50%     204.000000
# 75%     285.000000
# max     357.000000

# %%
product_df.sort_values(by="price", ascending=False)
# Out:
#       product_id product_type product_name size  colour  price  quantity  \
# 704          698       Jacket        Parka    L  violet    119        53
# 671          665       Jacket        Parka   XS     red    119        65
# 698          692       Jacket        Parka    M  indigo    119        66
# 699          693       Jacket        Parka    L  indigo    119        44
# 700          694       Jacket        Parka   XL  indigo    119        78
# ...          ...          ...          ...  ...     ...    ...       ...
# 1225        1219     Trousers      Pleated   XL  indigo     90        45
# 1226        1220     Trousers      Pleated   XS  violet     90        58
# 1227        1221     Trousers      Pleated    S  violet     90        50
# 1228        1222     Trousers      Pleated    M  violet     90        45
# 599          593       Jacket       Bomber    L  violet     90        68
#
#                                         description
# 704        A violet coloured, L sized, Parka Jacket
# 671          A red coloured, XS sized, Parka Jacket
# 698        A indigo coloured, M sized, Parka Jacket
# 699        A indigo coloured, L sized, Parka Jacket
# 700       A indigo coloured, XL sized, Parka Jacket
# ...                                             ...
# 1225  A indigo coloured, XL sized, Pleated Trousers
# 1226  A violet coloured, XS sized, Pleated Trousers
# 1227   A violet coloured, S sized, Pleated Trousers
# 1228   A violet coloured, M sized, Pleated Trousers
# 599       A violet coloured, L sized, Bomber Jacket
#
# [1260 rows x 8 columns]

# %% [markdown]
# mencari informasi terkait produk berdasarkan tipe dan nama produknya

# %%
product_df.groupby("product_type").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price":  ["min", "max"]
})
# Out:
#              product_id quantity price
#                 nunique      sum   min  max
# product_type
# Jacket              420    25387    90  119
# Shirt               420    25263    92  119
# Trousers            420    25139    90  119

# %%
product_df.groupby(by="product_name").agg({
    "product_id": "nunique",
    "quantity": "sum",
    "price": ["min", "max"]
})
# Out:
#                   product_id quantity price
#                      nunique      sum   min  max
# product_name
# Bomber                    35     2083    90   90
# Camp Collared             35     2071   112  112
# Cardigan                  35     2032   118  118
# Cargo Pants               35     2146   106  106
# Casual Slim Fit           35     2086   113  113
# Chambray                  35     2020   105  105
# Chinos                    35     2101   100  100
# Coach                     35     2158   115  115
# Cords                     35     2260   113  113
# Cropped                   35     2085    99   99
# Cuban Collar              35     2017    93   93
# Denim                     70     4204    92  115
# Drawstring                35     2042   104  104
# Dress                     35     2125   119  119
# Flannel                   35     2135    96   96
# Henley                    35     2051    92   92
# High-Waisted              35     2198    98   98
# Joggers                   35     2107    94   94
# Leather                   35     2276   113  113
# Linen                     35     2138   116  116
# Mandarin Collar           35     2203   108  108
# Oxford Cloth              35     2071   114  114
# Parka                     35     2201   119  119
# Peacoat                   35     2067   102  102
# Pleated                   35     2030    90   90
# Polo                      35     2196   117  117
# Puffer                    35     1946   110  110
# Pullover                  35     2184   114  114
# Relaxed Leg               35     2002    95   95
# Shearling                 35     2169    95   95
# Slim-Fit                  35     2155   119  119
# Tracksuit Bottoms         35     2038    91   91
# Trench Coat               35     2132   112  112
# Windbreaker               35     2085   109  109
# Wool                      35     1975   111  111

# %% [markdown]
# menyatukan tabel sales_df dan product_df

# %%
sales_product_df = pd.merge(
    left=sales_df,
    right=product_df,
    how="inner",
    left_on="product_id",
    right_on="product_id"
)
sales_product_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0         0         1         218             106           2          212
# 1      1129       233         218             106           3          318
# 2      4616       924         218             106           2          212
# 3         1         1         481             118           1          118
# 4       349        79         481             118           2          236
#
#   product_type product_name size  colour  price  quantity_y  \
# 0        Shirt     Chambray    L  orange    105          44
# 1        Shirt     Chambray    L  orange    105          44
# 2        Shirt     Chambray    L  orange    105          44
# 3       Jacket       Puffer    S  indigo    110          62
# 4       Jacket       Puffer    S  indigo    110          62
#
#                                   description
# 0  A orange coloured, L sized, Chambray Shirt
# 1  A orange coloured, L sized, Chambray Shirt
# 2  A orange coloured, L sized, Chambray Shirt
# 3   A indigo coloured, S sized, Puffer Jacket
# 4   A indigo coloured, S sized, Puffer Jacket

# %% [markdown]
# melihat informasi penjualan produk berdasarkan tipenya

# %%
sales_product_df.groupby("product_type").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": 'sum'
}).sort_values(by="total_price", ascending=False)
# Out:
#               sales_id  quantity_x  total_price
# product_type
# Jacket            1676        3343       357026
# Trousers          1683        3360       341174
# Shirt             1641        3259       333600

# %% [markdown]
# melihat informasi penjualan berdasarkan nama produk

# %%
sales_product_df.groupby(by="product_name").agg({
    "sales_id": "nunique",
    "quantity_x": "sum",
    "total_price": 'sum'
}).sort_values(by="total_price", ascending=False)
# Out:
#                    sales_id  quantity_x  total_price
# product_name
# Denim                   273         527        52399
# Casual Slim Fit         154         306        36414
# Trench Coat             146         299        35581
# Shearling               150         302        35334
# Puffer                  140         298        35164
# Flannel                 141         281        33158
# Cropped                 135         284        32660
# Pleated                 147         308        32340
# Joggers                 164         334        31062
# Chambray                141         290        30740
# Parka                   134         269        30397
# Bomber                  150         297        29700
# Chinos                  135         260        29380
# Windbreaker             143         287        29274
# Cardigan                134         260        29120
# Peacoat                 132         266        28994
# Tracksuit Bottoms       130         257        28784
# Slim-Fit                154         288        27936
# Oxford Cloth            146         289        27744
# Drawstring              147         288        27648
# High-Waisted            140         278        27522
# Camp Collared           139         279        27342
# Cargo Pants             134         267        27234
# Relaxed Leg             146         301        27090
# Cuban Collar            122         254        26670
# Henley                  146         281        26414
# Wool                    125         249        26394
# Leather                 136         263        25774
# Mandarin Collar         124         236        25724
# Dress                   127         243        25272
# Pullover                143         276        25116
# Polo                    131         264        25080
# Coach                   134         265        24645
# Linen                   131         270        24570
# Cords                   126         246        23124

# %% [markdown]
# Eksplorasi data all_df

# %%
all_df = pd.merge(
    left=sales_product_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_df
# Out:
#       sales_id  order_id  product_id  price_per_unit  quantity_x  total_price  \
# 0            0         1         218             106           2          212
# 1         1129       233         218             106           3          318
# 2         4616       924         218             106           2          212
# 3            1         1         481             118           1          118
# 4          349        79         481             118           2          236
# ...        ...       ...         ...             ...         ...          ...
# 4995      4848       970         510             102           1          102
# 4996      4864       973         255              95           3          285
# 4997      4883       977         735             109           2          218
# 4998      4912       982         659              93           2          186
# 4999      4998       999         998             106           2          212
#
#      product_type product_name size  colour  ...  customer_name  \
# 0           Shirt     Chambray    L  orange  ...       fulan 64
# 1           Shirt     Chambray    L  orange  ...      fulan 996
# 2           Shirt     Chambray    L  orange  ...      fulan 786
# 3          Jacket       Puffer    S  indigo  ...       fulan 64
# 4          Jacket       Puffer    S  indigo  ...      fulan 236
# ...           ...          ...  ...     ...  ...            ...
# 4995       Jacket  Windbreaker   XS    blue  ...      fulan 382
# 4996        Shirt         Polo   XS  yellow  ...      fulan 232
# 4997       Jacket      Peacoat   XS     red  ...      fulan 463
# 4998       Jacket        Coach   XL  indigo  ...      fulan 123
# 4999     Trousers         Wool    L   green  ...      fulan 428
#
#                  gender age                  home_address  zip_code  \
# 0     Prefer not to say  75     4927 Alice MeadowApt. 960      7787
# 1     Prefer not to say  59  0433 Armstrong HillSuite 974      7613
# 2     Prefer not to say  23    145 Abigail SummitApt. 514      4731
# 3     Prefer not to say  75     4927 Alice MeadowApt. 960      7787
# 4     Prefer not to say  80       64 Phillips RunApt. 722      2752
# ...                 ...  ..                           ...       ...
# 4995  Prefer not to say  24       83 Jordan DriveApt. 011      6714
# 4996               Male  24  8982 O'reilly PlazaSuite 007      5019
# 4997  Prefer not to say  58     00 Lockman TrackSuite 564       387
# 4998             Female  22    8083 Paterson RoadApt. 211      1149
# 4999  Prefer not to say  66     80 Hermiston WaySuite 403      1112
#
#                    city                         state    country  status  \
# 0        Sanfordborough               South Australia  Australia  Active
# 1       Lake Danielland                      Tasmania  Australia  Active
# 2            Graceville               New South Wales  Australia  Active
# 3        Sanfordborough               South Australia  Australia  Active
# 4           East Sienna               New South Wales  Australia  Active
# ...                 ...                           ...        ...     ...
# 4995      Rodriguezbury                      Victoria  Australia  Active
# 4996       Lake Matilda            Northern Territory  Australia  Active
# 4997  Lake Mikaylashire  Australian Capital Territory  Australia  Active
# 4998      Jordanborough                      Tasmania  Australia  Active
# 4999     North Liamfort  Australian Capital Territory  Australia  Active
#
#      age_group
# 0      Seniors
# 1       Adults
# 2        Youth
# 3      Seniors
# 4      Seniors
# ...        ...
# 4995     Youth
# 4996     Youth
# 4997    Adults
# 4998     Youth
# 4999   Seniors
#
# [5000 rows x 28 columns]

# %% [markdown]
# melihat preferensi pembelian berdasarkan state pelanggan dan tipe produk

# %%
all_df.groupby(by=["state", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                            quantity_x  total_price
# state                        product_type
# Australian Capital Territory Jacket               406        43204
#                              Shirt                396        40448
#                              Trousers             454        46790
# New South Wales              Jacket               451        47998
#                              Shirt                431        43980
#                              Trousers             392        39766
# Northern Territory           Jacket               365        38991
#                              Shirt                336        33865
#                              Trousers             384        38998
# Queensland                   Jacket               499        53511
#                              Shirt                417        42506
#                              Trousers             453        46045
# South Australia              Jacket               461        49090
#                              Shirt                509        52685
#                              Trousers             455        46041
# Tasmania                     Jacket               412        44370
#                              Shirt                387        39668
#                              Trousers             379        38057
# Victoria                     Jacket               359        38203
#                              Shirt                390        40206
#                              Trousers             414        41948
# Western Australia            Jacket               390        41659
#                              Shirt                393        40242
#                              Trousers             429        43529

# %% [markdown]
# mengetahui selera tipe produk pelanggan berdasarkan gender

# %%
all_df.groupby(by=["gender", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                                 quantity_x  total_price
# gender            product_type
# Female            Jacket               481        50963
#                   Shirt                445        45146
#                   Trousers             481        49295
# Male              Jacket               480        50978
#                   Shirt                410        41939
#                   Trousers             453        46071
# Prefer not to say Jacket              2382       255085
#                   Shirt               2404       246515
#                   Trousers            2426       245808

# %% [markdown]
# mengetahui selera tipe produk pelanggan berdasarkan kelompok usia

# %%
all_df.groupby(by=["age_group", "product_type"]).agg({
    "quantity_x": "sum",
    "total_price": "sum"
})
# Out:
#                         quantity_x  total_price
# age_group product_type
# Adults    Jacket              2292       245055
#           Shirt               2225       227781
#           Trousers            2272       231271
# Seniors   Jacket               777        82959
#           Shirt                733        74977
#           Trousers             766        77471
# Youth     Jacket               274        29012
#           Shirt                301        30842
#           Trousers             322        32432

# %% [markdown]
# **Data Visualization**

# %% [markdown]
# Bagaimana performa penjualan dan revenue perusahaan dalam beberapa bulan terakhir?

# %%
#melakukan resample data order_date menjadi bulanan serta melakukan agregasi
monthly_orders_df = all_df.resample(rule='M', on='order_date').agg({
    "order_id": "nunique",
    "total_price": "sum"
})
monthly_orders_df.index = monthly_orders_df.index.strftime('%Y-%m')
monthly_orders_df = monthly_orders_df.reset_index()
monthly_orders_df.rename(columns={
    "order_id": "order_count",
    "total_price": "revenue"
}, inplace=True)
monthly_orders_df.head()
# Out:
#   order_date  order_count  revenue
# 0    2021-01          109   119333
# 1    2021-02           93    95080
# 2    2021-03          117   131364
# 3    2021-04           99    97530
# 4    2021-05           84    85597

# %% [markdown]
# memvisualkan informasi terkait jumlah order yang diperoleh tiap bulan

# %%
plt.figure(figsize=(10, 5))
plt.plot(monthly_orders_df["order_date"], monthly_orders_df["order_count"], marker='o', linewidth=2, color="blue")
plt.title("Number of Orders per Month (2021)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# memvisualkan informasi terkait total revenue yang diperoleh tiap bulan

# %%
plt.figure(figsize=(10, 5))
plt.plot(
    monthly_orders_df["order_date"],
    monthly_orders_df["revenue"],
    marker='o',
    linewidth=2,
    color="#72BCD4"
)
plt.title("Total Revenue per Month in 2021 (AUD)", loc="center", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# Produk Apa yang Paling Banyak dan Paling Sedikit Terjual?

# %%
sum_order_items_df = all_df.groupby("product_name").quantity_x.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(15)
# Out:
#        product_name  quantity_x
# 0             Denim         527
# 1           Joggers         334
# 2           Pleated         308
# 3   Casual Slim Fit         306
# 4         Shearling         302
# 5       Relaxed Leg         301
# 6       Trench Coat         299
# 7            Puffer         298
# 8            Bomber         297
# 9          Chambray         290
# 10     Oxford Cloth         289
# 11       Drawstring         288
# 12         Slim-Fit         288
# 13      Windbreaker         287
# 14          Cropped         284

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="quantity_x", y="product_name", data=sum_order_items_df.sort_values(by="quantity_x", ascending=True).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=20)
plt.show()

# %% [markdown]
# Bagaimana Demografi Pelanggan yang Kita Miliki?

# %%
bygender_df = all_df.groupby(by="gender").customer_id.nunique().reset_index()
bygender_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)

plt.figure(figsize=(10, 5))

sns.barplot(
    y="customer_count",
    x="gender",
    data=bygender_df.sort_values(by="customer_count", ascending=False),
    palette=colors
)
plt.title("Number of Customer by Gender", loc="center", fontsize=15)
plt.ylabel(None)
# Out:
# Text(0, 0.5, '')

# %%
byage_df = all_df.groupby(by="age_group").customer_id.nunique().reset_index()
byage_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
byage_df
byage_df['age_group'] = pd.Categorical(byage_df['age_group'], ["Youth", "Adults", "Seniors"])
plt.figure(figsize=(10, 5))
colors_ = ["#D3D3D3", "#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(
    y="customer_count",
    x="age_group",
    data=byage_df.sort_values(by="age_group", ascending=False),
    palette=colors_
)
plt.title("Number of Customer by Age", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()

# %% [markdown]
# Berdasarkan State

# %%
bystate_df = all_df.groupby(by="state")['customer_id'].nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    palette=colors_
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# RFM Analysis

# %%
rfm_df = all_df.groupby(by="customer_id", as_index=False).agg({
    "order_date": "max", # mengambil tanggal order terakhir
    "order_id": "nunique", # menghitung jumlah order
    "total_price": "sum" # menghitung jumlah revenue yang dihasilkan
})
rfm_df.columns = ["customer_id", "max_order_timestamp", "frequency", "monetary"]

# menghitung kapan terakhir pelanggan melakukan transaksi (hari)
rfm_df["max_order_timestamp"] = rfm_df["max_order_timestamp"].dt.date
recent_date = orders_df["order_date"].dt.date.max()
rfm_df["recency"] = rfm_df["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm_df.drop("max_order_timestamp", axis=1, inplace=True)
rfm_df.head()
# Out:
#    customer_id  frequency  monetary  recency
# 0            1          3      1641      203
# 1            7          1      1017      156
# 2           10          1       270      229
# 3           11          1       382      149
# 4           12          1      1551      127

# %% [markdown]
#  mengidentifikasi best customer berdasarkan parameter frequency, monetary, dan recancy

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30, 6))

colors = ["#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4", "#72BCD4"]

sns.barplot(y="recency", x="customer_id", data=rfm_df.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis ='x', labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm_df.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis='x', labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm_df.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis='x', labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()

# %%
all_df.to_csv("data_input/all_data.csv", index=False)
